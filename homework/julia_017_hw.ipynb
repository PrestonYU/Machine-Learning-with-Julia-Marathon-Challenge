# %% [markdown]
# # Julia DataFrames.jl 介紹
#
# # Day 017 作業：載入 COVID-19 資料集
#
# 今天的作業將使用 `DataFrames.jl` 及 `CSV.jl` 套件，來載入美國約翰霍普金斯大學提供的 COVID-19 資料集 (2019 Novel Coronavirus COVID-19 (2019-nCoV) Data Repository by Johns Hopkins CSSE)。資料集作為教育及研究使用，並且被用來建立視覺化儀表板提供檢視及追蹤 COVID-19 疫情狀況。
#
# 資料集 GitHub: [https://github.com/CSSEGISandData/COVID-19](https://github.com/CSSEGISandData/COVID-19)
#
# 資料集格式為 CSV，整合不同資料來源，主要分為 Daily Report 及時間序列資料。
#
# 請自行下載 2020/4/2 的 daily report資料集：[https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv)
#
# Daily Report 主要欄位有：
#
# - Province/State: 省名 (中國)、州名或市名 (美國、加拿大、澳洲)、或是事件名稱 (例如鑽石公主號)...
# - Country/Region: 國名或區域名
# - Last Update: 最後更新日期/時間，格式為 24 小時制的 UTC 時間
# - Confirmed: 確診案例
# - Deaths: 死亡案例
# - Recovered: 康復案例
# - Lat, Long: 經緯度
# - Combined Key: 複合 Key 值

# %%
using DataFrames, CSV
# Out:
# ┌ Info: Recompiling stale cache file /Users/prestonyu9011/.julia/compiled/v1.2/DataFrames/AR9oZ.ji for DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1240
# ┌ Info: Recompiling stale cache file /Users/prestonyu9011/.julia/compiled/v1.2/CSV/HHBkp.ji for CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1240

# %%
# 撰寫讀取 CSV 檔的程式碼
df = CSV.read("04-02-2020.csv")
# Out:
# ┌ Warning: `CSV.read(input; kw...)` is deprecated in favor of `CSV.read(input, DataFrame; kw...)
# └ @ CSV /Users/prestonyu9011/.julia/packages/CSV/vohbW/src/CSV.jl:41
# 2569×12 DataFrame. Omitted printing of 8 columns
# │ Row  │ FIPS    │ Admin2     │ Province_State │ Country_Region       │
# │      │ Int64?  │ String?    │ String?        │ String               │
# ├──────┼─────────┼────────────┼────────────────┼──────────────────────┤
# │ 1    │ 45001   │ Abbeville  │ South Carolina │ US                   │
# │ 2    │ 22001   │ Acadia     │ Louisiana      │ US                   │
# │ 3    │ 51001   │ Accomack   │ Virginia       │ US                   │
# │ 4    │ 16001   │ Ada        │ Idaho          │ US                   │
# │ 5    │ 19001   │ Adair      │ Iowa           │ US                   │
# │ 6    │ 29001   │ Adair      │ Missouri       │ US                   │
# │ 7    │ 40001   │ Adair      │ Oklahoma       │ US                   │
# │ 8    │ 8001    │ Adams      │ Colorado       │ US                   │
# │ 9    │ 16003   │ Adams      │ Idaho          │ US                   │
# │ 10   │ 17001   │ Adams      │ Illinois       │ US                   │
# ⋮
# │ 2559 │ missing │ missing    │ missing        │ Ukraine              │
# │ 2560 │ missing │ missing    │ missing        │ United Arab Emirates │
# │ 2561 │ missing │ missing    │ missing        │ United Kingdom       │
# │ 2562 │ missing │ missing    │ missing        │ Uruguay              │
# │ 2563 │ missing │ missing    │ missing        │ Uzbekistan           │
# │ 2564 │ missing │ missing    │ missing        │ Venezuela            │
# │ 2565 │ missing │ missing    │ missing        │ Vietnam              │
# │ 2566 │ missing │ missing    │ missing        │ West Bank and Gaza   │
# │ 2567 │ missing │ missing    │ missing        │ Zambia               │
# │ 2568 │ missing │ missing    │ missing        │ Zimbabwe             │
# │ 2569 │ missing │ unassigned │ Wyoming        │ US                   │

# %% [markdown]
# 請問此資料集的筆數 (row) 及欄位數 (column) 各是多少？

# %%
# 請在此輸入程式碼
println("Number of rows: $(size(df, 1))")
println("Number of columns: $(size(df, 2))")
# Out:
# Number of rows: 2569
# Number of columns: 12

# %%
# 彙總 DataFrame 資訊
describe(df)
# Out:
# 12×8 DataFrame. Omitted printing of 4 columns
# │ Row │ variable       │ mean     │ min                 │ median   │
# │     │ Symbol         │ Union…   │ Any                 │ Union…   │
# ├─────┼────────────────┼──────────┼─────────────────────┼──────────┤
# │ 1   │ FIPS           │ 30958.4  │ 66                  │ 29093.0  │
# │ 2   │ Admin2         │          │ Abbeville           │          │
# │ 3   │ Province_State │          │ Alabama             │          │
# │ 4   │ Country_Region │          │ Afghanistan         │          │
# │ 5   │ Last_Update    │          │ 2020-02-23 11:19:02 │          │
# │ 6   │ Lat            │ 36.2992  │ -42.8821            │ 37.7171  │
# │ 7   │ Long_          │ -78.9577 │ -159.597            │ -86.5104 │
# │ 8   │ Confirmed      │ 394.378  │ 0                   │ 7.0      │
# │ 9   │ Deaths         │ 20.624   │ 0                   │ 0.0      │
# │ 10  │ Recovered      │ 81.8462  │ 0                   │ 0.0      │
# │ 11  │ Active         │ 199.29   │ 0                   │ 0.0      │
# │ 12  │ Combined_Key   │          │ ,,Belize            │          │

# %% [markdown]
# ### 作業1：數值 Column 的計算
#
# 請問截至4月2日為止 (UTC 時間)，全球累計的確診、死亡、及㡽復案例數各是多少？
#
# 【提示】可參考 `sum()` 內建函式。

# %%
names(df)
# Out:
# 12-element Array{String,1}:
#  "FIPS"
#  "Admin2"
#  "Province_State"
#  "Country_Region"
#  "Last_Update"
#  "Lat"
#  "Long_"
#  "Confirmed"
#  "Deaths"
#  "Recovered"
#  "Active"
#  "Combined_Key"

# %%
# map(sum, [df[:, name] for name in names(df) if name in (:Confirmed, :Deaths, :Recovered)])

println("All over the world until 2020/04/02,
    Confirmed: $(sum(df.Confirmed))
    Deaths: $(sum(df.Deaths))
    Recovered: $(sum(df.Recovered))")
# Out:
# All over the world until 2020/04/02,
#     Confirmed: 1013157
#     Deaths: 52983
#     Recovered: 210263

# %%
using Statistics
df_sum =  aggregate(df[:, [:Confirmed, :Deaths, :Recovered]], [sum])
println("All over the world until 2020/04/02,
    Confirmed: $(sum(df_sum.Confirmed_sum))
    Deaths: $(sum(df_sum.Deaths_sum))
    Recovered: $(sum(df_sum.Recovered_sum))")
# Out:
# All over the world until 2020/04/02,
#     Confirmed: 1013157
#     Deaths: 52983
#     Recovered: 210263
# ┌ Warning: `aggregate(d, fs)` is deprecated. Instead use `combine(d, [names(d) .=> f for f in fs]...)` if functions in `fs` have unique names.
# │   caller = top-level scope at In[7]:2
# └ @ Core In[7]:2

# %%
df_Confirmed_top10 = first(sort(df, :Confirmed, rev=true), 10)
df_Confirmed_top10[!, [:Province_State, :Country_Region, :Confirmed, :Deaths, :Recovered]]
# Out:
# 10×5 DataFrame
# │ Row │ Province_State │ Country_Region │ Confirmed │ Deaths │ Recovered │
# │     │ String?        │ String         │ Int64     │ Int64  │ Int64     │
# ├─────┼────────────────┼────────────────┼───────────┼────────┼───────────┤
# │ 1   │ missing        │ Italy          │ 115242    │ 13915  │ 18278     │
# │ 2   │ missing        │ Spain          │ 112065    │ 10348  │ 26743     │
# │ 3   │ missing        │ Germany        │ 84794     │ 1107   │ 22440     │
# │ 4   │ Hubei          │ China          │ 67802     │ 3199   │ 63471     │
# │ 5   │ missing        │ France         │ 59105     │ 5387   │ 12428     │
# │ 6   │ New York       │ US             │ 51809     │ 1397   │ 0         │
# │ 7   │ missing        │ Iran           │ 50468     │ 3160   │ 16711     │
# │ 8   │ missing        │ United Kingdom │ 33718     │ 2921   │ 135       │
# │ 9   │ missing        │ Switzerland    │ 18827     │ 536    │ 4013      │
# │ 10  │ missing        │ Turkey         │ 18135     │ 356    │ 415       │

# %% [markdown]
# 上面解答範例列出確診案例數前 10 名的 Province_State, Country_Region, Confirmed, Deaths, Recovered 等 5 個 column。

# %% [markdown]
# ### 作業2：找出特定的 Row
#
# 截至4月2日為止 (UTC 時間)，台灣的確診、死亡、及㡽復案例數為多少？
#
# 【提示】使用點運算 `.==` 來比較同一 column 中所有值。

# %%
# Find the string representing Taiwan in the Country_Region column
show(df[:, [:Country_Region]]; allrows=true)
# Out:
# 2569×1 DataFrame
# │ Row  │ Country_Region                   │
# │      │ String                           │
# ├──────┼──────────────────────────────────┤
# │ 1    │ US                               │
# │ 2    │ US                               │
# │ 3    │ US                               │
# │ 4    │ US                               │
# │ 5    │ US                               │
# │ 6    │ US                               │
# │ 7    │ US                               │
# │ 8    │ US                               │
# │ 9    │ US                               │
# │ 10   │ US                               │
# │ 11   │ US                               │
# │ 12   │ US                               │
# │ 13   │ US                               │
# │ 14   │ US                               │
# │ 15   │ US                               │
# │ 16   │ US                               │
# │ 17   │ US                               │
# │ 18   │ US                               │
# │ 19   │ US                               │
# │ 20   │ US                               │
# │ 21   │ US                               │
# │ 22   │ US                               │
# │ 23   │ US                               │
# │ 24   │ US                               │
# │ 25   │ US                               │
# │ 26   │ US                               │
# │ 27   │ US                               │
# │ 28   │ US                               │
# │ 29   │ US                               │
# │ 30   │ US                               │
# │ 31   │ US                               │
# │ 32   │ US                               │
# │ 33   │ US                               │
# │ 34   │ US                               │
# │ 35   │ US                               │
# │ 36   │ US                               │
# │ 37   │ US                               │
# │ 38   │ US                               │
# │ 39   │ US                               │
# │ 40   │ US                               │
# │ 41   │ US                               │
# │ 42   │ US                               │
# │ 43   │ US                               │
# │ 44   │ US                               │
# │ 45   │ US                               │
# │ 46   │ US                               │
# │ 47   │ US                               │
# │ 48   │ US                               │
# │ 49   │ US                               │
# │ 50   │ US                               │
# │ 51   │ US                               │
# │ 52   │ US                               │
# │ 53   │ US                               │
# │ 54   │ US                               │
# │ 55   │ US                               │
# │ 56   │ US                               │
# │ 57   │ US                               │
# │ 58   │ US                               │
# │ 59   │ US                               │
# │ 60   │ US                               │
# │ 61   │ US                               │
# │ 62   │ US                               │
# │ 63   │ US                               │
# │ 64   │ US                               │
# │ 65   │ US                               │
# │ 66   │ US                               │
# │ 67   │ US                               │
# │ 68   │ US                               │
# │ 69   │ US                               │
# │ 70   │ US                               │
# │ 71   │ US                               │
# │ 72   │ US                               │
# │ 73   │ US                               │
# │ 74   │ US                               │
# │ 75   │ US                               │
# │ 76   │ US                               │
# │ 77   │ US                               │
# │ 78   │ US                               │
# │ 79   │ US                               │
# │ 80   │ US                               │
# │ 81   │ US                               │
# │ 82   │ US                               │
# │ 83   │ US                               │
# │ 84   │ US                               │
# │ 85   │ US                               │
# │ 86   │ US                               │
# │ 87   │ US                               │
# │ 88   │ US                               │
# │ 89   │ US                               │
# │ 90   │ US                               │
# │ 91   │ US                               │
# │ 92   │ US                               │
# │ 93   │ US                               │
# │ 94   │ US                               │
# │ 95   │ US                               │
# │ 96   │ US                               │
# │ 97   │ US                               │
# │ 98   │ US                               │
# │ 99   │ US                               │
# │ 100  │ US                               │
# │ 101  │ US                               │
# │ 102  │ US                               │
# │ 103  │ US                               │
# │ 104  │ US                               │
# │ 105  │ US                               │
# │ 106  │ US                               │
# │ 107  │ US                               │
# │ 108  │ US                               │
# │ 109  │ US                               │
# │ 110  │ US                               │
# │ 111  │ US                               │
# │ 112  │ US                               │
# │ 113  │ US                               │
# │ 114  │ US                               │
# │ 115  │ US                               │
# │ 116  │ US                               │
# │ 117  │ US                               │
# │ 118  │ US                               │
# │ 119  │ US                               │
# │ 120  │ US                               │
# │ 121  │ US                               │
# │ 122  │ US                               │
# │ 123  │ US                               │
# │ 124  │ US                               │
# │ 125  │ US                               │
# │ 126  │ US                               │
# │ 127  │ US                               │
# │ 128  │ US                               │
# │ 129  │ US                               │
# │ 130  │ US                               │
# │ 131  │ US                               │
# │ 132  │ US                               │
# │ 133  │ US                               │
# │ 134  │ US                               │
# │ 135  │ US                               │
# │ 136  │ US                               │
# │ 137  │ US                               │
# │ 138  │ US                               │
# │ 139  │ US                               │
# │ 140  │ US                               │
# │ 141  │ US                               │
# │ 142  │ US                               │
# │ 143  │ US                               │
# │ 144  │ US                               │
# │ 145  │ US                               │
# │ 146  │ US                               │
# │ 147  │ US                               │
# │ 148  │ US                               │
# │ 149  │ US                               │
# │ 150  │ US                               │
# │ 151  │ US                               │
# │ 152  │ US                               │
# │ 153  │ US                               │
# │ 154  │ US                               │
# │ 155  │ US                               │
# │ 156  │ US                               │
# │ 157  │ US                               │
# │ 158  │ US                               │
# │ 159  │ US                               │
# │ 160  │ US                               │
# │ 161  │ US                               │
# │ 162  │ US                               │
# │ 163  │ US                               │
# │ 164  │ US                               │
# │ 165  │ US                               │
# │ 166  │ US                               │
# │ 167  │ US                               │
# │ 168  │ US                               │
# │ 169  │ US                               │
# │ 170  │ US                               │
# │ 171  │ US                               │
# │ 172  │ US                               │
# │ 173  │ US                               │
# │ 174  │ US                               │
# │ 175  │ US                               │
# │ 176  │ US                               │
# │ 177  │ US                               │
# │ 178  │ US                               │
# │ 179  │ US                               │
# │ 180  │ US                               │
# │ 181  │ US                               │
# │ 182  │ US                               │
# │ 183  │ US                               │
# │ 184  │ US                               │
# │ 185  │ US                               │
# │ 186  │ US                               │
# │ 187  │ US                               │
# │ 188  │ US                               │
# │ 189  │ US                               │
# │ 190  │ US                               │
# │ 191  │ US                               │
# │ 192  │ US                               │
# │ 193  │ US                               │
# │ 194  │ US                               │
# │ 195  │ US                               │
# │ 196  │ US                               │
# │ 197  │ US                               │
# │ 198  │ US                               │
# │ 199  │ US                               │
# │ 200  │ US                               │
# │ 201  │ US                               │
# │ 202  │ US                               │
# │ 203  │ US                               │
# │ 204  │ US                               │
# │ 205  │ US                               │
# │ 206  │ US                               │
# │ 207  │ US                               │
# │ 208  │ US                               │
# │ 209  │ US                               │
# │ 210  │ US                               │
# │ 211  │ US                               │
# │ 212  │ US                               │
# │ 213  │ US                               │
# │ 214  │ US                               │
# │ 215  │ US                               │
# │ 216  │ US                               │
# │ 217  │ US                               │
# │ 218  │ US                               │
# │ 219  │ US                               │
# │ 220  │ US                               │
# │ 221  │ US                               │
# │ 222  │ US                               │
# │ 223  │ US                               │
# │ 224  │ US                               │
# │ 225  │ US                               │
# │ 226  │ US                               │
# │ 227  │ US                               │
# │ 228  │ US                               │
# │ 229  │ US                               │
# │ 230  │ US                               │
# │ 231  │ US                               │
# │ 232  │ US                               │
# │ 233  │ US                               │
# │ 234  │ US                               │
# │ 235  │ US                               │
# │ 236  │ US                               │
# │ 237  │ US                               │
# │ 238  │ US                               │
# │ 239  │ US                               │
# │ 240  │ US                               │
# │ 241  │ US                               │
# │ 242  │ US                               │
# │ 243  │ US                               │
# │ 244  │ US                               │
# │ 245  │ US                               │
# │ 246  │ US                               │
# │ 247  │ US                               │
# │ 248  │ US                               │
# │ 249  │ US                               │
# │ 250  │ US                               │
# │ 251  │ US                               │
# │ 252  │ US                               │
# │ 253  │ US                               │
# │ 254  │ US                               │
# │ 255  │ US                               │
# │ 256  │ US                               │
# │ 257  │ US                               │
# │ 258  │ US                               │
# │ 259  │ US                               │
# │ 260  │ US                               │
# │ 261  │ US                               │
# │ 262  │ US                               │
# │ 263  │ US                               │
# │ 264  │ US                               │
# │ 265  │ US                               │
# │ 266  │ US                               │
# │ 267  │ US                               │
# │ 268  │ US                               │
# │ 269  │ US                               │
# │ 270  │ US                               │
# │ 271  │ US                               │
# │ 272  │ US                               │
# │ 273  │ US                               │
# │ 274  │ US                               │
# │ 275  │ US                               │
# │ 276  │ US                               │
# │ 277  │ US                               │
# │ 278  │ US                               │
# │ 279  │ US                               │
# │ 280  │ US                               │
# │ 281  │ US                               │
# │ 282  │ US                               │
# │ 283  │ US                               │
# │ 284  │ US                               │
# │ 285  │ US                               │
# │ 286  │ US                               │
# │ 287  │ US                               │
# │ 288  │ US                               │
# │ 289  │ US                               │
# │ 290  │ US                               │
# │ 291  │ US                               │
# │ 292  │ US                               │
# │ 293  │ US                               │
# │ 294  │ US                               │
# │ 295  │ US                               │
# │ 296  │ US                               │
# │ 297  │ US                               │
# │ 298  │ US                               │
# │ 299  │ US                               │
# │ 300  │ US                               │
# │ 301  │ US                               │
# │ 302  │ US                               │
# │ 303  │ US                               │
# │ 304  │ US                               │
# │ 305  │ US                               │
# │ 306  │ US                               │
# │ 307  │ US                               │
# │ 308  │ US                               │
# │ 309  │ US                               │
# │ 310  │ US                               │
# │ 311  │ US                               │
# │ 312  │ US                               │
# │ 313  │ US                               │
# │ 314  │ US                               │
# │ 315  │ US                               │
# │ 316  │ US                               │
# │ 317  │ US                               │
# │ 318  │ US                               │
# │ 319  │ US                               │
# │ 320  │ US                               │
# │ 321  │ US                               │
# │ 322  │ US                               │
# │ 323  │ US                               │
# │ 324  │ US                               │
# │ 325  │ US                               │
# │ 326  │ US                               │
# │ 327  │ US                               │
# │ 328  │ US                               │
# │ 329  │ US                               │
# │ 330  │ US                               │
# │ 331  │ US                               │
# │ 332  │ US                               │
# │ 333  │ US                               │
# │ 334  │ US                               │
# │ 335  │ US                               │
# │ 336  │ US                               │
# │ 337  │ US                               │
# │ 338  │ US                               │
# │ 339  │ US                               │
# │ 340  │ US                               │
# │ 341  │ US                               │
# │ 342  │ US                               │
# │ 343  │ US                               │
# │ 344  │ US                               │
# │ 345  │ US                               │
# │ 346  │ US                               │
# │ 347  │ US                               │
# │ 348  │ US                               │
# │ 349  │ US                               │
# │ 350  │ US                               │
# │ 351  │ US                               │
# │ 352  │ US                               │
# │ 353  │ US                               │
# │ 354  │ US                               │
# │ 355  │ US                               │
# │ 356  │ US                               │
# │ 357  │ US                               │
# │ 358  │ US                               │
# │ 359  │ US                               │
# │ 360  │ US                               │
# │ 361  │ US                               │
# │ 362  │ US                               │
# │ 363  │ US                               │
# │ 364  │ US                               │
# │ 365  │ US                               │
# │ 366  │ US                               │
# │ 367  │ US                               │
# │ 368  │ US                               │
# │ 369  │ US                               │
# │ 370  │ US                               │
# │ 371  │ US                               │
# │ 372  │ US                               │
# │ 373  │ US                               │
# │ 374  │ US                               │
# │ 375  │ US                               │
# │ 376  │ US                               │
# │ 377  │ US                               │
# │ 378  │ US                               │
# │ 379  │ US                               │
# │ 380  │ US                               │
# │ 381  │ US                               │
# │ 382  │ US                               │
# │ 383  │ US                               │
# │ 384  │ US                               │
# │ 385  │ US                               │
# │ 386  │ US                               │
# │ 387  │ US                               │
# │ 388  │ US                               │
# │ 389  │ US                               │
# │ 390  │ US                               │
# │ 391  │ US                               │
# │ 392  │ US                               │
# │ 393  │ US                               │
# │ 394  │ US                               │
# │ 395  │ US                               │
# │ 396  │ US                               │
# │ 397  │ US                               │
# │ 398  │ US                               │
# │ 399  │ US                               │
# │ 400  │ US                               │
# │ 401  │ US                               │
# │ 402  │ US                               │
# │ 403  │ US                               │
# │ 404  │ US                               │
# │ 405  │ US                               │
# │ 406  │ US                               │
# │ 407  │ US                               │
# │ 408  │ US                               │
# │ 409  │ US                               │
# │ 410  │ US                               │
# │ 411  │ US                               │
# │ 412  │ US                               │
# │ 413  │ US                               │
# │ 414  │ US                               │
# │ 415  │ US                               │
# │ 416  │ US                               │
# │ 417  │ US                               │
# │ 418  │ US                               │
# │ 419  │ US                               │
# │ 420  │ US                               │
# │ 421  │ US                               │
# │ 422  │ US                               │
# │ 423  │ US                               │
# │ 424  │ US                               │
# │ 425  │ US                               │
# │ 426  │ US                               │
# │ 427  │ US                               │
# │ 428  │ US                               │
# │ 429  │ US                               │
# │ 430  │ US                               │
# │ 431  │ US                               │
# │ 432  │ US                               │
# │ 433  │ US                               │
# │ 434  │ US                               │
# │ 435  │ US                               │
# │ 436  │ US                               │
# │ 437  │ US                               │
# │ 438  │ US                               │
# │ 439  │ US                               │
# │ 440  │ US                               │
# │ 441  │ US                               │
# │ 442  │ US                               │
# │ 443  │ US                               │
# │ 444  │ US                               │
# │ 445  │ US                               │
# │ 446  │ US                               │
# │ 447  │ US                               │
# │ 448  │ US                               │
# │ 449  │ US                               │
# │ 450  │ US                               │
# │ 451  │ US                               │
# │ 452  │ US                               │
# │ 453  │ US                               │
# │ 454  │ US                               │
# │ 455  │ US                               │
# │ 456  │ US                               │
# │ 457  │ US                               │
# │ 458  │ US                               │
# │ 459  │ US                               │
# │ 460  │ US                               │
# │ 461  │ US                               │
# │ 462  │ US                               │
# │ 463  │ US                               │
# │ 464  │ US                               │
# │ 465  │ US                               │
# │ 466  │ US                               │
# │ 467  │ US                               │
# │ 468  │ US                               │
# │ 469  │ US                               │
# │ 470  │ US                               │
# │ 471  │ US                               │
# │ 472  │ US                               │
# │ 473  │ US                               │
# │ 474  │ US                               │
# │ 475  │ US                               │
# │ 476  │ US                               │
# │ 477  │ US                               │
# │ 478  │ US                               │
# │ 479  │ US                               │
# │ 480  │ US                               │
# │ 481  │ US                               │
# │ 482  │ US                               │
# │ 483  │ US                               │
# │ 484  │ US                               │
# │ 485  │ US                               │
# │ 486  │ US                               │
# │ 487  │ US                               │
# │ 488  │ US                               │
# │ 489  │ US                               │
# │ 490  │ US                               │
# │ 491  │ US                               │
# │ 492  │ US                               │
# │ 493  │ US                               │
# │ 494  │ US                               │
# │ 495  │ US                               │
# │ 496  │ US                               │
# │ 497  │ US                               │
# │ 498  │ US                               │
# │ 499  │ US                               │
# │ 500  │ US                               │
# │ 501  │ US                               │
# │ 502  │ US                               │
# │ 503  │ US                               │
# │ 504  │ US                               │
# │ 505  │ US                               │
# │ 506  │ US                               │
# │ 507  │ US                               │
# │ 508  │ US                               │
# │ 509  │ US                               │
# │ 510  │ US                               │
# │ 511  │ US                               │
# │ 512  │ US                               │
# │ 513  │ US                               │
# │ 514  │ US                               │
# │ 515  │ US                               │
# │ 516  │ US                               │
# │ 517  │ US                               │
# │ 518  │ US                               │
# │ 519  │ US                               │
# │ 520  │ US                               │
# │ 521  │ US                               │
# │ 522  │ US                               │
# │ 523  │ US                               │
# │ 524  │ US                               │
# │ 525  │ US                               │
# │ 526  │ US                               │
# │ 527  │ US                               │
# │ 528  │ US                               │
# │ 529  │ US                               │
# │ 530  │ US                               │
# │ 531  │ US                               │
# │ 532  │ US                               │
# │ 533  │ US                               │
# │ 534  │ US                               │
# │ 535  │ US                               │
# │ 536  │ US                               │
# │ 537  │ US                               │
# │ 538  │ US                               │
# │ 539  │ US                               │
# │ 540  │ US                               │
# │ 541  │ US                               │
# │ 542  │ US                               │
# │ 543  │ US                               │
# │ 544  │ US                               │
# │ 545  │ US                               │
# │ 546  │ US                               │
# │ 547  │ US                               │
# │ 548  │ US                               │
# │ 549  │ US                               │
# │ 550  │ US                               │
# │ 551  │ US                               │
# │ 552  │ US                               │
# │ 553  │ US                               │
# │ 554  │ US                               │
# │ 555  │ US                               │
# │ 556  │ US                               │
# │ 557  │ US                               │
# │ 558  │ US                               │
# │ 559  │ US                               │
# │ 560  │ US                               │
# │ 561  │ US                               │
# │ 562  │ US                               │
# │ 563  │ US                               │
# │ 564  │ US                               │
# │ 565  │ US                               │
# │ 566  │ US                               │
# │ 567  │ US                               │
# │ 568  │ US                               │
# │ 569  │ US                               │
# │ 570  │ US                               │
# │ 571  │ US                               │
# │ 572  │ US                               │
# │ 573  │ US                               │
# │ 574  │ US                               │
# │ 575  │ US                               │
# │ 576  │ US                               │
# │ 577  │ US                               │
# │ 578  │ US                               │
# │ 579  │ US                               │
# │ 580  │ US                               │
# │ 581  │ US                               │
# │ 582  │ US                               │
# │ 583  │ US                               │
# │ 584  │ US                               │
# │ 585  │ US                               │
# │ 586  │ US                               │
# │ 587  │ US                               │
# │ 588  │ US                               │
# │ 589  │ US                               │
# │ 590  │ US                               │
# │ 591  │ US                               │
# │ 592  │ US                               │
# │ 593  │ US                               │
# │ 594  │ US                               │
# │ 595  │ US                               │
# │ 596  │ US                               │
# │ 597  │ US                               │
# │ 598  │ US                               │
# │ 599  │ US                               │
# │ 600  │ US                               │
# │ 601  │ US                               │
# │ 602  │ US                               │
# │ 603  │ US                               │
# │ 604  │ US                               │
# │ 605  │ US                               │
# │ 606  │ US                               │
# │ 607  │ US                               │
# │ 608  │ US                               │
# │ 609  │ US                               │
# │ 610  │ US                               │
# │ 611  │ US                               │
# │ 612  │ US                               │
# │ 613  │ US                               │
# │ 614  │ US                               │
# │ 615  │ US                               │
# │ 616  │ US                               │
# │ 617  │ US                               │
# │ 618  │ US                               │
# │ 619  │ US                               │
# │ 620  │ US                               │
# │ 621  │ US                               │
# │ 622  │ US                               │
# │ 623  │ US                               │
# │ 624  │ US                               │
# │ 625  │ US                               │
# │ 626  │ US                               │
# │ 627  │ US                               │
# │ 628  │ US                               │
# │ 629  │ US                               │
# │ 630  │ US                               │
# │ 631  │ US                               │
# │ 632  │ US                               │
# │ 633  │ US                               │
# │ 634  │ US                               │
# │ 635  │ US                               │
# │ 636  │ US                               │
# │ 637  │ US                               │
# │ 638  │ US                               │
# │ 639  │ US                               │
# │ 640  │ US                               │
# │ 641  │ US                               │
# │ 642  │ US                               │
# │ 643  │ US                               │
# │ 644  │ US                               │
# │ 645  │ US                               │
# │ 646  │ US                               │
# │ 647  │ US                               │
# │ 648  │ US                               │
# │ 649  │ US                               │
# │ 650  │ US                               │
# │ 651  │ US                               │
# │ 652  │ US                               │
# │ 653  │ US                               │
# │ 654  │ US                               │
# │ 655  │ US                               │
# │ 656  │ US                               │
# │ 657  │ US                               │
# │ 658  │ US                               │
# │ 659  │ US                               │
# │ 660  │ US                               │
# │ 661  │ US                               │
# │ 662  │ US                               │
# │ 663  │ US                               │
# │ 664  │ US                               │
# │ 665  │ US                               │
# │ 666  │ US                               │
# │ 667  │ US                               │
# │ 668  │ US                               │
# │ 669  │ US                               │
# │ 670  │ US                               │
# │ 671  │ US                               │
# │ 672  │ US                               │
# │ 673  │ US                               │
# │ 674  │ US                               │
# │ 675  │ US                               │
# │ 676  │ US                               │
# │ 677  │ US                               │
# │ 678  │ US                               │
# │ 679  │ US                               │
# │ 680  │ US                               │
# │ 681  │ US                               │
# │ 682  │ US                               │
# │ 683  │ US                               │
# │ 684  │ US                               │
# │ 685  │ US                               │
# │ 686  │ US                               │
# │ 687  │ US                               │
# │ 688  │ US                               │
# │ 689  │ US                               │
# │ 690  │ US                               │
# │ 691  │ US                               │
# │ 692  │ US                               │
# │ 693  │ US                               │
# │ 694  │ US                               │
# │ 695  │ US                               │
# │ 696  │ US                               │
# │ 697  │ US                               │
# │ 698  │ US                               │
# │ 699  │ US                               │
# │ 700  │ US                               │
# │ 701  │ US                               │
# │ 702  │ US                               │
# │ 703  │ US                               │
# │ 704  │ US                               │
# │ 705  │ US                               │
# │ 706  │ US                               │
# │ 707  │ US                               │
# │ 708  │ US                               │
# │ 709  │ US                               │
# │ 710  │ US                               │
# │ 711  │ US                               │
# │ 712  │ US                               │
# │ 713  │ US                               │
# │ 714  │ US                               │
# │ 715  │ US                               │
# │ 716  │ US                               │
# │ 717  │ US                               │
# │ 718  │ US                               │
# │ 719  │ US                               │
# │ 720  │ US                               │
# │ 721  │ US                               │
# │ 722  │ US                               │
# │ 723  │ US                               │
# │ 724  │ US                               │
# │ 725  │ US                               │
# │ 726  │ US                               │
# │ 727  │ US                               │
# │ 728  │ US                               │
# │ 729  │ US                               │
# │ 730  │ US                               │
# │ 731  │ US                               │
# │ 732  │ US                               │
# │ 733  │ US                               │
# │ 734  │ US                               │
# │ 735  │ US                               │
# │ 736  │ US                               │
# │ 737  │ US                               │
# │ 738  │ US                               │
# │ 739  │ US                               │
# │ 740  │ US                               │
# │ 741  │ US                               │
# │ 742  │ US                               │
# │ 743  │ US                               │
# │ 744  │ US                               │
# │ 745  │ US                               │
# │ 746  │ US                               │
# │ 747  │ US                               │
# │ 748  │ US                               │
# │ 749  │ US                               │
# │ 750  │ US                               │
# │ 751  │ US                               │
# │ 752  │ US                               │
# │ 753  │ US                               │
# │ 754  │ US                               │
# │ 755  │ US                               │
# │ 756  │ US                               │
# │ 757  │ US                               │
# │ 758  │ US                               │
# │ 759  │ US                               │
# │ 760  │ US                               │
# │ 761  │ US                               │
# │ 762  │ US                               │
# │ 763  │ US                               │
# │ 764  │ US                               │
# │ 765  │ US                               │
# │ 766  │ US                               │
# │ 767  │ US                               │
# │ 768  │ US                               │
# │ 769  │ US                               │
# │ 770  │ US                               │
# │ 771  │ US                               │
# │ 772  │ US                               │
# │ 773  │ US                               │
# │ 774  │ US                               │
# │ 775  │ US                               │
# │ 776  │ US                               │
# │ 777  │ US                               │
# │ 778  │ US                               │
# │ 779  │ US                               │
# │ 780  │ US                               │
# │ 781  │ US                               │
# │ 782  │ US                               │
# │ 783  │ US                               │
# │ 784  │ US                               │
# │ 785  │ US                               │
# │ 786  │ US                               │
# │ 787  │ US                               │
# │ 788  │ US                               │
# │ 789  │ US                               │
# │ 790  │ US                               │
# │ 791  │ US                               │
# │ 792  │ US                               │
# │ 793  │ US                               │
# │ 794  │ US                               │
# │ 795  │ US                               │
# │ 796  │ US                               │
# │ 797  │ US                               │
# │ 798  │ US                               │
# │ 799  │ US                               │
# │ 800  │ US                               │
# │ 801  │ US                               │
# │ 802  │ US                               │
# │ 803  │ US                               │
# │ 804  │ US                               │
# │ 805  │ US                               │
# │ 806  │ US                               │
# │ 807  │ US                               │
# │ 808  │ US                               │
# │ 809  │ US                               │
# │ 810  │ US                               │
# │ 811  │ US                               │
# │ 812  │ US                               │
# │ 813  │ US                               │
# │ 814  │ US                               │
# │ 815  │ US                               │
# │ 816  │ US                               │
# │ 817  │ US                               │
# │ 818  │ US                               │
# │ 819  │ US                               │
# │ 820  │ US                               │
# │ 821  │ US                               │
# │ 822  │ US                               │
# │ 823  │ US                               │
# │ 824  │ US                               │
# │ 825  │ US                               │
# │ 826  │ US                               │
# │ 827  │ US                               │
# │ 828  │ US                               │
# │ 829  │ US                               │
# │ 830  │ US                               │
# │ 831  │ US                               │
# │ 832  │ US                               │
# │ 833  │ US                               │
# │ 834  │ US                               │
# │ 835  │ US                               │
# │ 836  │ US                               │
# │ 837  │ US                               │
# │ 838  │ US                               │
# │ 839  │ US                               │
# │ 840  │ US                               │
# │ 841  │ US                               │
# │ 842  │ US                               │
# │ 843  │ US                               │
# │ 844  │ US                               │
# │ 845  │ US                               │
# │ 846  │ US                               │
# │ 847  │ US                               │
# │ 848  │ US                               │
# │ 849  │ US                               │
# │ 850  │ US                               │
# │ 851  │ US                               │
# │ 852  │ US                               │
# │ 853  │ US                               │
# │ 854  │ US                               │
# │ 855  │ US                               │
# │ 856  │ US                               │
# │ 857  │ US                               │
# │ 858  │ US                               │
# │ 859  │ US                               │
# │ 860  │ US                               │
# │ 861  │ US                               │
# │ 862  │ US                               │
# │ 863  │ US                               │
# │ 864  │ US                               │
# │ 865  │ US                               │
# │ 866  │ US                               │
# │ 867  │ US                               │
# │ 868  │ US                               │
# │ 869  │ US                               │
# │ 870  │ US                               │
# │ 871  │ US                               │
# │ 872  │ US                               │
# │ 873  │ US                               │
# │ 874  │ US                               │
# │ 875  │ US                               │
# │ 876  │ US                               │
# │ 877  │ US                               │
# │ 878  │ US                               │
# │ 879  │ US                               │
# │ 880  │ US                               │
# │ 881  │ US                               │
# │ 882  │ US                               │
# │ 883  │ US                               │
# │ 884  │ US                               │
# │ 885  │ US                               │
# │ 886  │ US                               │
# │ 887  │ US                               │
# │ 888  │ US                               │
# │ 889  │ US                               │
# │ 890  │ US                               │
# │ 891  │ US                               │
# │ 892  │ US                               │
# │ 893  │ US                               │
# │ 894  │ US                               │
# │ 895  │ US                               │
# │ 896  │ US                               │
# │ 897  │ US                               │
# │ 898  │ US                               │
# │ 899  │ US                               │
# │ 900  │ US                               │
# │ 901  │ US                               │
# │ 902  │ US                               │
# │ 903  │ US                               │
# │ 904  │ US                               │
# │ 905  │ US                               │
# │ 906  │ US                               │
# │ 907  │ US                               │
# │ 908  │ US                               │
# │ 909  │ US                               │
# │ 910  │ US                               │
# │ 911  │ US                               │
# │ 912  │ US                               │
# │ 913  │ US                               │
# │ 914  │ US                               │
# │ 915  │ US                               │
# │ 916  │ US                               │
# │ 917  │ US                               │
# │ 918  │ US                               │
# │ 919  │ US                               │
# │ 920  │ US                               │
# │ 921  │ US                               │
# │ 922  │ US                               │
# │ 923  │ US                               │
# │ 924  │ US                               │
# │ 925  │ US                               │
# │ 926  │ US                               │
# │ 927  │ US                               │
# │ 928  │ US                               │
# │ 929  │ US                               │
# │ 930  │ US                               │
# │ 931  │ US                               │
# │ 932  │ US                               │
# │ 933  │ US                               │
# │ 934  │ US                               │
# │ 935  │ US                               │
# │ 936  │ US                               │
# │ 937  │ US                               │
# │ 938  │ US                               │
# │ 939  │ US                               │
# │ 940  │ US                               │
# │ 941  │ US                               │
# │ 942  │ US                               │
# │ 943  │ US                               │
# │ 944  │ US                               │
# │ 945  │ US                               │
# │ 946  │ US                               │
# │ 947  │ US                               │
# │ 948  │ US                               │
# │ 949  │ US                               │
# │ 950  │ US                               │
# │ 951  │ US                               │
# │ 952  │ US                               │
# │ 953  │ US                               │
# │ 954  │ US                               │
# │ 955  │ US                               │
# │ 956  │ US                               │
# │ 957  │ US                               │
# │ 958  │ US                               │
# │ 959  │ US                               │
# │ 960  │ US                               │
# │ 961  │ US                               │
# │ 962  │ US                               │
# │ 963  │ US                               │
# │ 964  │ US                               │
# │ 965  │ US                               │
# │ 966  │ US                               │
# │ 967  │ US                               │
# │ 968  │ US                               │
# │ 969  │ US                               │
# │ 970  │ US                               │
# │ 971  │ US                               │
# │ 972  │ US                               │
# │ 973  │ US                               │
# │ 974  │ US                               │
# │ 975  │ US                               │
# │ 976  │ US                               │
# │ 977  │ US                               │
# │ 978  │ US                               │
# │ 979  │ US                               │
# │ 980  │ US                               │
# │ 981  │ US                               │
# │ 982  │ US                               │
# │ 983  │ US                               │
# │ 984  │ US                               │
# │ 985  │ US                               │
# │ 986  │ US                               │
# │ 987  │ US                               │
# │ 988  │ US                               │
# │ 989  │ US                               │
# │ 990  │ US                               │
# │ 991  │ US                               │
# │ 992  │ US                               │
# │ 993  │ US                               │
# │ 994  │ US                               │
# │ 995  │ US                               │
# │ 996  │ US                               │
# │ 997  │ US                               │
# │ 998  │ US                               │
# │ 999  │ US                               │
# │ 1000 │ US                               │
# │ 1001 │ US                               │
# │ 1002 │ US                               │
# │ 1003 │ US                               │
# │ 1004 │ US                               │
# │ 1005 │ US                               │
# │ 1006 │ US                               │
# │ 1007 │ US                               │
# │ 1008 │ US                               │
# │ 1009 │ US                               │
# │ 1010 │ US                               │
# │ 1011 │ US                               │
# │ 1012 │ US                               │
# │ 1013 │ US                               │
# │ 1014 │ US                               │
# │ 1015 │ US                               │
# │ 1016 │ US                               │
# │ 1017 │ US                               │
# │ 1018 │ US                               │
# │ 1019 │ US                               │
# │ 1020 │ US                               │
# │ 1021 │ US                               │
# │ 1022 │ US                               │
# │ 1023 │ US                               │
# │ 1024 │ US                               │
# │ 1025 │ US                               │
# │ 1026 │ US                               │
# │ 1027 │ US                               │
# │ 1028 │ US                               │
# │ 1029 │ US                               │
# │ 1030 │ US                               │
# │ 1031 │ US                               │
# │ 1032 │ US                               │
# │ 1033 │ US                               │
# │ 1034 │ US                               │
# │ 1035 │ US                               │
# │ 1036 │ US                               │
# │ 1037 │ US                               │
# │ 1038 │ US                               │
# │ 1039 │ US                               │
# │ 1040 │ US                               │
# │ 1041 │ US                               │
# │ 1042 │ US                               │
# │ 1043 │ US                               │
# │ 1044 │ US                               │
# │ 1045 │ US                               │
# │ 1046 │ US                               │
# │ 1047 │ US                               │
# │ 1048 │ US                               │
# │ 1049 │ US                               │
# │ 1050 │ US                               │
# │ 1051 │ US                               │
# │ 1052 │ US                               │
# │ 1053 │ US                               │
# │ 1054 │ US                               │
# │ 1055 │ US                               │
# │ 1056 │ US                               │
# │ 1057 │ US                               │
# │ 1058 │ US                               │
# │ 1059 │ US                               │
# │ 1060 │ US                               │
# │ 1061 │ US                               │
# │ 1062 │ US                               │
# │ 1063 │ US                               │
# │ 1064 │ US                               │
# │ 1065 │ US                               │
# │ 1066 │ US                               │
# │ 1067 │ US                               │
# │ 1068 │ US                               │
# │ 1069 │ US                               │
# │ 1070 │ US                               │
# │ 1071 │ US                               │
# │ 1072 │ US                               │
# │ 1073 │ US                               │
# │ 1074 │ US                               │
# │ 1075 │ US                               │
# │ 1076 │ US                               │
# │ 1077 │ US                               │
# │ 1078 │ US                               │
# │ 1079 │ US                               │
# │ 1080 │ US                               │
# │ 1081 │ US                               │
# │ 1082 │ US                               │
# │ 1083 │ US                               │
# │ 1084 │ US                               │
# │ 1085 │ US                               │
# │ 1086 │ US                               │
# │ 1087 │ US                               │
# ...
# │ 2207 │ US                               │
# │ 2208 │ US                               │
# │ 2209 │ US                               │
# │ 2210 │ US                               │
# │ 2211 │ US                               │
# │ 2212 │ US                               │
# │ 2213 │ US                               │
# │ 2214 │ US                               │
# │ 2215 │ US                               │
# │ 2216 │ US                               │
# │ 2217 │ US                               │
# │ 2218 │ US                               │
# │ 2219 │ US                               │
# │ 2220 │ US                               │
# │ 2221 │ US                               │
# │ 2222 │ US                               │
# │ 2223 │ US                               │
# │ 2224 │ US                               │
# │ 2225 │ US                               │
# │ 2226 │ US                               │
# │ 2227 │ US                               │
# │ 2228 │ US                               │
# │ 2229 │ US                               │
# │ 2230 │ US                               │
# │ 2231 │ US                               │
# │ 2232 │ US                               │
# │ 2233 │ US                               │
# │ 2234 │ US                               │
# │ 2235 │ US                               │
# │ 2236 │ US                               │
# │ 2237 │ US                               │
# │ 2238 │ US                               │
# │ 2239 │ US                               │
# │ 2240 │ US                               │
# │ 2241 │ US                               │
# │ 2242 │ US                               │
# │ 2243 │ US                               │
# │ 2244 │ US                               │
# │ 2245 │ US                               │
# │ 2246 │ US                               │
# │ 2247 │ US                               │
# │ 2248 │ US                               │
# │ 2249 │ US                               │
# │ 2250 │ US                               │
# │ 2251 │ US                               │
# │ 2252 │ US                               │
# │ 2253 │ US                               │
# │ 2254 │ US                               │
# │ 2255 │ US                               │
# │ 2256 │ US                               │
# │ 2257 │ US                               │
# │ 2258 │ US                               │
# │ 2259 │ US                               │
# │ 2260 │ US                               │
# │ 2261 │ US                               │
# │ 2262 │ US                               │
# │ 2263 │ US                               │
# │ 2264 │ US                               │
# │ 2265 │ US                               │
# │ 2266 │ US                               │
# │ 2267 │ US                               │
# │ 2268 │ US                               │
# │ 2269 │ US                               │
# │ 2270 │ US                               │
# │ 2271 │ US                               │
# │ 2272 │ US                               │
# │ 2273 │ US                               │
# │ 2274 │ US                               │
# │ 2275 │ US                               │
# │ 2276 │ US                               │
# │ 2277 │ US                               │
# │ 2278 │ US                               │
# │ 2279 │ US                               │
# │ 2280 │ US                               │
# │ 2281 │ US                               │
# │ 2282 │ US                               │
# │ 2283 │ US                               │
# │ 2284 │ US                               │
# │ 2285 │ US                               │
# │ 2286 │ US                               │
# │ 2287 │ US                               │
# │ 2288 │ US                               │
# │ 2289 │ US                               │
# │ 2290 │ US                               │
# │ 2291 │ US                               │
# │ 2292 │ US                               │
# │ 2293 │ US                               │
# │ 2294 │ US                               │
# │ 2295 │ US                               │
# │ 2296 │ US                               │
# │ 2297 │ US                               │
# │ 2298 │ US                               │
# │ 2299 │ US                               │
# │ 2300 │ US                               │
# │ 2301 │ US                               │
# │ 2302 │ US                               │
# │ 2303 │ US                               │
# │ 2304 │ US                               │
# │ 2305 │ Canada                           │
# │ 2306 │ United Kingdom                   │
# │ 2307 │ China                            │
# │ 2308 │ Netherlands                      │
# │ 2309 │ Australia                        │
# │ 2310 │ China                            │
# │ 2311 │ United Kingdom                   │
# │ 2312 │ Netherlands                      │
# │ 2313 │ Canada                           │
# │ 2314 │ United Kingdom                   │
# │ 2315 │ United Kingdom                   │
# │ 2316 │ United Kingdom                   │
# │ 2317 │ China                            │
# │ 2318 │ Netherlands                      │
# │ 2319 │ Canada                           │
# │ 2320 │ US                               │
# │ 2321 │ Denmark                          │
# │ 2322 │ France                           │
# │ 2323 │ France                           │
# │ 2324 │ China                            │
# │ 2325 │ China                            │
# │ 2326 │ United Kingdom                   │
# │ 2327 │ Canada                           │
# │ 2328 │ US                               │
# │ 2329 │ Denmark                          │
# │ 2330 │ France                           │
# │ 2331 │ US                               │
# │ 2332 │ China                            │
# │ 2333 │ China                            │
# │ 2334 │ China                            │
# │ 2335 │ China                            │
# │ 2336 │ China                            │
# │ 2337 │ China                            │
# │ 2338 │ China                            │
# │ 2339 │ China                            │
# │ 2340 │ China                            │
# │ 2341 │ China                            │
# │ 2342 │ China                            │
# │ 2343 │ United Kingdom                   │
# │ 2344 │ China                            │
# │ 2345 │ China                            │
# │ 2346 │ China                            │
# │ 2347 │ China                            │
# │ 2348 │ China                            │
# │ 2349 │ Canada                           │
# │ 2350 │ France                           │
# │ 2351 │ France                           │
# │ 2352 │ United Kingdom                   │
# │ 2353 │ Canada                           │
# │ 2354 │ France                           │
# │ 2355 │ Australia                        │
# │ 2356 │ Canada                           │
# │ 2357 │ China                            │
# │ 2358 │ US                               │
# │ 2359 │ Australia                        │
# │ 2360 │ Canada                           │
# │ 2361 │ Canada                           │
# │ 2362 │ Canada                           │
# │ 2363 │ Canada                           │
# │ 2364 │ US                               │
# │ 2365 │ China                            │
# │ 2366 │ Canada                           │
# │ 2367 │ Australia                        │
# │ 2368 │ Canada                           │
# │ 2369 │ US                               │
# │ 2370 │ France                           │
# │ 2371 │ France                           │
# │ 2372 │ Canada                           │
# │ 2373 │ China                            │
# │ 2374 │ China                            │
# │ 2375 │ China                            │
# │ 2376 │ China                            │
# │ 2377 │ China                            │
# │ 2378 │ Netherlands                      │
# │ 2379 │ Australia                        │
# │ 2380 │ France                           │
# │ 2381 │ Australia                        │
# │ 2382 │ China                            │
# │ 2383 │ China                            │
# │ 2384 │ United Kingdom                   │
# │ 2385 │ Australia                        │
# │ 2386 │ US                               │
# │ 2387 │ Australia                        │
# │ 2388 │ China                            │
# │ 2389 │ Canada                           │
# │ 2390 │ China                            │
# │ 2391 │ China                            │
# │ 2392 │ Afghanistan                      │
# │ 2393 │ Albania                          │
# │ 2394 │ Algeria                          │
# │ 2395 │ Andorra                          │
# │ 2396 │ Angola                           │
# │ 2397 │ Antigua and Barbuda              │
# │ 2398 │ Argentina                        │
# │ 2399 │ Armenia                          │
# │ 2400 │ Austria                          │
# │ 2401 │ Azerbaijan                       │
# │ 2402 │ Bahamas                          │
# │ 2403 │ Bahrain                          │
# │ 2404 │ Bangladesh                       │
# │ 2405 │ Barbados                         │
# │ 2406 │ Belarus                          │
# │ 2407 │ Belgium                          │
# │ 2408 │ Belize                           │
# │ 2409 │ Benin                            │
# │ 2410 │ Bhutan                           │
# │ 2411 │ Bolivia                          │
# │ 2412 │ Bosnia and Herzegovina           │
# │ 2413 │ Botswana                         │
# │ 2414 │ Brazil                           │
# │ 2415 │ Brunei                           │
# │ 2416 │ Bulgaria                         │
# │ 2417 │ Burkina Faso                     │
# │ 2418 │ Burma                            │
# │ 2419 │ Burundi                          │
# │ 2420 │ Cabo Verde                       │
# │ 2421 │ Cambodia                         │
# │ 2422 │ Cameroon                         │
# │ 2423 │ Central African Republic         │
# │ 2424 │ Chad                             │
# │ 2425 │ Chile                            │
# │ 2426 │ Colombia                         │
# │ 2427 │ Congo (Brazzaville)              │
# │ 2428 │ Congo (Kinshasa)                 │
# │ 2429 │ Costa Rica                       │
# │ 2430 │ Cote d'Ivoire                    │
# │ 2431 │ Croatia                          │
# │ 2432 │ Cuba                             │
# │ 2433 │ Cyprus                           │
# │ 2434 │ Czechia                          │
# │ 2435 │ Denmark                          │
# │ 2436 │ Diamond Princess                 │
# │ 2437 │ Djibouti                         │
# │ 2438 │ Dominica                         │
# │ 2439 │ Dominican Republic               │
# │ 2440 │ Ecuador                          │
# │ 2441 │ Egypt                            │
# │ 2442 │ El Salvador                      │
# │ 2443 │ Equatorial Guinea                │
# │ 2444 │ Eritrea                          │
# │ 2445 │ Estonia                          │
# │ 2446 │ Eswatini                         │
# │ 2447 │ Ethiopia                         │
# │ 2448 │ Fiji                             │
# │ 2449 │ Finland                          │
# │ 2450 │ France                           │
# │ 2451 │ Gabon                            │
# │ 2452 │ Gambia                           │
# │ 2453 │ Georgia                          │
# │ 2454 │ Germany                          │
# │ 2455 │ Ghana                            │
# │ 2456 │ Greece                           │
# │ 2457 │ Grenada                          │
# │ 2458 │ Guatemala                        │
# │ 2459 │ Guinea                           │
# │ 2460 │ Guinea-Bissau                    │
# │ 2461 │ Guyana                           │
# │ 2462 │ Haiti                            │
# │ 2463 │ Holy See                         │
# │ 2464 │ Honduras                         │
# │ 2465 │ Hungary                          │
# │ 2466 │ Iceland                          │
# │ 2467 │ India                            │
# │ 2468 │ Indonesia                        │
# │ 2469 │ Iran                             │
# │ 2470 │ Iraq                             │
# │ 2471 │ Ireland                          │
# │ 2472 │ Israel                           │
# │ 2473 │ Italy                            │
# │ 2474 │ Jamaica                          │
# │ 2475 │ Japan                            │
# │ 2476 │ Jordan                           │
# │ 2477 │ Kazakhstan                       │
# │ 2478 │ Kenya                            │
# │ 2479 │ Korea, South                     │
# │ 2480 │ Kosovo                           │
# │ 2481 │ Kuwait                           │
# │ 2482 │ Kyrgyzstan                       │
# │ 2483 │ Laos                             │
# │ 2484 │ Latvia                           │
# │ 2485 │ Lebanon                          │
# │ 2486 │ Liberia                          │
# │ 2487 │ Libya                            │
# │ 2488 │ Liechtenstein                    │
# │ 2489 │ Lithuania                        │
# │ 2490 │ Luxembourg                       │
# │ 2491 │ MS Zaandam                       │
# │ 2492 │ Madagascar                       │
# │ 2493 │ Malawi                           │
# │ 2494 │ Malaysia                         │
# │ 2495 │ Maldives                         │
# │ 2496 │ Mali                             │
# │ 2497 │ Malta                            │
# │ 2498 │ Mauritania                       │
# │ 2499 │ Mauritius                        │
# │ 2500 │ Mexico                           │
# │ 2501 │ Moldova                          │
# │ 2502 │ Monaco                           │
# │ 2503 │ Mongolia                         │
# │ 2504 │ Montenegro                       │
# │ 2505 │ Morocco                          │
# │ 2506 │ Mozambique                       │
# │ 2507 │ Namibia                          │
# │ 2508 │ Nepal                            │
# │ 2509 │ Netherlands                      │
# │ 2510 │ New Zealand                      │
# │ 2511 │ Nicaragua                        │
# │ 2512 │ Niger                            │
# │ 2513 │ Nigeria                          │
# │ 2514 │ North Macedonia                  │
# │ 2515 │ Norway                           │
# │ 2516 │ Oman                             │
# │ 2517 │ Pakistan                         │
# │ 2518 │ Panama                           │
# │ 2519 │ Papua New Guinea                 │
# │ 2520 │ Paraguay                         │
# │ 2521 │ Peru                             │
# │ 2522 │ Philippines                      │
# │ 2523 │ Poland                           │
# │ 2524 │ Portugal                         │
# │ 2525 │ Qatar                            │
# │ 2526 │ Romania                          │
# │ 2527 │ Russia                           │
# │ 2528 │ Rwanda                           │
# │ 2529 │ Saint Kitts and Nevis            │
# │ 2530 │ Saint Lucia                      │
# │ 2531 │ Saint Vincent and the Grenadines │
# │ 2532 │ San Marino                       │
# │ 2533 │ Saudi Arabia                     │
# │ 2534 │ Senegal                          │
# │ 2535 │ Serbia                           │
# │ 2536 │ Seychelles                       │
# │ 2537 │ Sierra Leone                     │
# │ 2538 │ Singapore                        │
# │ 2539 │ Slovakia                         │
# │ 2540 │ Slovenia                         │
# │ 2541 │ Somalia                          │
# │ 2542 │ South Africa                     │
# │ 2543 │ Spain                            │
# │ 2544 │ Sri Lanka                        │
# │ 2545 │ Sudan                            │
# │ 2546 │ Suriname                         │
# │ 2547 │ Sweden                           │
# │ 2548 │ Switzerland                      │
# │ 2549 │ Syria                            │
# │ 2550 │ Taiwan*                          │
# │ 2551 │ Tanzania                         │
# │ 2552 │ Thailand                         │
# │ 2553 │ Timor-Leste                      │
# │ 2554 │ Togo                             │
# │ 2555 │ Trinidad and Tobago              │
# │ 2556 │ Tunisia                          │
# │ 2557 │ Turkey                           │
# │ 2558 │ Uganda                           │
# │ 2559 │ Ukraine                          │
# │ 2560 │ United Arab Emirates             │
# │ 2561 │ United Kingdom                   │
# │ 2562 │ Uruguay                          │
# │ 2563 │ Uzbekistan                       │
# │ 2564 │ Venezuela                        │
# │ 2565 │ Vietnam                          │
# │ 2566 │ West Bank and Gaza               │
# │ 2567 │ Zambia                           │
# │ 2568 │ Zimbabwe                         │
# │ 2569 │ US                               │

# %%
df_taiwan = df[df[:, :Country_Region] .== "Taiwan*", :]
# Out:
# 1×12 DataFrame. Omitted printing of 8 columns
# │ Row │ FIPS    │ Admin2  │ Province_State │ Country_Region │
# │     │ Int64?  │ String? │ String?        │ String         │
# ├─────┼─────────┼─────────┼────────────────┼────────────────┤
# │ 1   │ missing │ missing │ missing        │ Taiwan*        │

# %%
println("In Taiwan until 2020/04/02,
    Confirmed: $(sum(df_taiwan.Confirmed))
    Deaths: $(sum(df_taiwan.Deaths))
    Recovered: $(sum(df_taiwan.Recovered))")
# Out:
# In Taiwan until 2020/04/02,
#     Confirmed: 339
#     Deaths: 5
#     Recovered: 45
